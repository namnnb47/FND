# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 import numpy as np
import pandas as pd

# %%
# load the data
df1 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/fake_or_real_news.csv")
df2 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/Fake.csv")
df3 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/fnn_dev.csv")

# %%
df1
# Out:
#       Unnamed: 0  ... label
# 0           8476  ...  FAKE
# 1          10294  ...  FAKE
# 2           3608  ...  REAL
# 3          10142  ...  FAKE
# 4            875  ...  REAL
# ...          ...  ...   ...
# 6330        4490  ...  REAL
# 6331        8062  ...  FAKE
# 6332        8622  ...  FAKE
# 6333        4021  ...  REAL
# 6334        4330  ...  REAL
#
# [6335 rows x 4 columns]

# %%
df1.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df1.drop(columns=['title'],inplace=True)

# %%
for i in range(0,len(df1)):
  if df1['label'][i] == 'FAKE':
    df1['label'][i] = 1
  if df1['label'][i] == 'REAL':
    df1['label'][i] = 0

# %%
df3.drop(columns=['id'], inplace=True)
df3.drop(columns=['speaker'], inplace=True)
df3.drop(columns=['statement'], inplace=True)
df3.drop(columns=['date'], inplace=True)
df3.drop(columns=['sources'], inplace=True)
df3.drop(columns=['paragraph_based_content'], inplace=True)

# %%
df3['text'] = df3['fullText_based_content']
df3.drop(columns=['fullText_based_content'], inplace=True)
df3['isfake'] = df3['label_fnn']
df3.drop(columns=['label_fnn'], inplace=True)

# %%
for i in range(0,len(df3)):
  if df1['label'][i] == 'fake':
    df1['label'][i] = 1
  if df1['label'][i] == 'real':
    df1['label'][i] = 0

# %%
df3
# Out:
#                                                    text isfake
# 0     Gov. Charlie Crist launched what amounts to a ...   fake
# 1     U.S. Rep. Bobby Scott, D-3rd, was not pleased ...   real
# 2     Amid reports questioning Foxconn Technology Gr...   fake
# 3     State Sen. Dave Aronberg, a Democratic candida...   real
# 4     From the citrus of the Rio Grande Valley to th...   fake
# ...                                                 ...    ...
# 1053  In  a Facebook post Wednesday, Democratic gube...   fake
# 1054  A Republican group says that when Richard Cord...   fake
# 1055  On Feb. 23, 2015, the night before a hearing t...   real
# 1056  President Donald Trump famously said , "When s...   fake
# 1057  Democrats ripping jobs gains under Republican ...   real
#
# [1058 rows x 2 columns]

# %%
df2.drop(columns=['title'], inplace=True)
df2.drop(columns=['subject'], inplace=True)
df2.drop(columns=['date'], inplace=True)

# %%
df2['isfake']=1

# %%
df2
# Out:
#                                                     text  isfake
# 0      Donald Trump just couldn t wish all Americans ...       1
# 1      House Intelligence Committee Chairman Devin Nu...       1
# 2      On Friday, it was revealed that former Milwauk...       1
# 3      On Christmas day, Donald Trump announced that ...       1
# 4      Pope Francis used his annual Christmas Day mes...       1
# ...                                                  ...     ...
# 23476  21st Century Wire says As 21WIRE reported earl...       1
# 23477  21st Century Wire says It s a familiar theme. ...       1
# 23478  Patrick Henningsen  21st Century WireRemember ...       1
# 23479  21st Century Wire says Al Jazeera America will...       1
# 23480  21st Century Wire says As 21WIRE predicted in ...       1
#
# [23481 rows x 2 columns]

# %%
# load the data
df4 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/fnn_test.csv")
df5 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/fnn_train.csv")
df6 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/gossipcop_fake.csv")

# %%
df4.drop(columns=['id'], inplace=True)
df4.drop(columns=['speaker'], inplace=True)
df4.drop(columns=['statement'], inplace=True)
df4.drop(columns=['date'], inplace=True)
df4.drop(columns=['sources'], inplace=True)
df4.drop(columns=['paragraph_based_content'], inplace=True)
df4['text'] = df4['fullText_based_content']
df4.drop(columns=['fullText_based_content'], inplace=True)
df4['isfake'] = df4['label_fnn']
df4.drop(columns=['label_fnn'], inplace=True)

# %%
for i in range(0,len(df4)):
  if df4['isfake'][i] == 'fake':
    df4['isfake'][i] = 1
  if df4['isfake'][i] == 'real':
    df4['isfake'][i] = 0

# %%
df5.drop(columns=['id'], inplace=True)
df5.drop(columns=['speaker'], inplace=True)
df5.drop(columns=['statement'], inplace=True)
df5.drop(columns=['date'], inplace=True)
df5.drop(columns=['sources'], inplace=True)
df5.drop(columns=['paragraph_based_content'], inplace=True)
df5['text'] = df5['fullText_based_content']
df5.drop(columns=['fullText_based_content'], inplace=True)
df5['isfake'] = df5['label_fnn']
df5.drop(columns=['label_fnn'], inplace=True)

# %%
for i in range(0,len(df5)):
  if df5['isfake'][i] == 'fake':
    df5['isfake'][i] = 1
  if df5['isfake'][i] == 'real':
    df5['isfake'][i] = 0

# %%
df6.dropna(subset=['text'], inplace=True)

# %%
df6
# Out:
#                                                    text  isfake
# 0     Did Miley Cyrus and Liam Hemsworth secretly ge...       1
# 1     Paris Jackson & Cara Delevingne Enjoy Night Ou...       1
# 2     Celebrities Join Tax March in Protest of Donal...       1
# 3     Cindy Crawford's daughter Kaia Gerber wears a ...       1
# 4         Full List of 2018 Oscar Nominations – Variety       1
# ...                                                 ...     ...
# 5330   September 11: Celebrities Remember 9/11 (TWEETS)       1
# 5331  NASCAR owners threaten to fire drivers who pro...       1
# 5332  The 7 signs that David Beckham is definitely h...       1
# 5333  Ryan Gosling and Eva Mendes Did Not Get Marrie...       1
# 5334  Jamie Foxx Spends the Day With Katie Holmes an...       1
#
# [5323 rows x 2 columns]

# %%
# load the data
df7 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/gossipcop_real.csv")
df8 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/politifact_fake.csv")
df9 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/politifact_real.csv")

# %%
df7['isfake']=0

# %%
df9['isfake']=0

# %%
df1['isfake']=df['label']
df1.drop(columns='label', inplace=True)

# %%
df1
# Out:
#                                                    text isfake
# 0     Daniel Greenfield, a Shillman Journalism Fello...      1
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...      1
# 2     U.S. Secretary of State John F. Kerry said Mon...      0
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...      1
# 4     It's primary day in New York and front-runners...      0
# ...                                                 ...    ...
# 6330  The State Department told the Republican Natio...      0
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...      1
# 6332   Anti-Trump Protesters Are Tools of the Oligar...      1
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...      0
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...      0
#
# [6335 rows x 2 columns]

# %%
# load the data
df10 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/test.csv")
df11 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/train.csv")
df12 = pd.read_csv("/content/drive/My Drive/fnd-usingML/dataset/raw/True.csv")

# %%
df11.drop(columns=['id'], inplace=True)
df11.drop(columns=['title'], inplace=True)
df11.drop(columns=['author'], inplace=True)
df11['isfake'] = df11['label']
df11.drop(columns=['label'], inplace=True)

# %%
df11
# Out:
#                                                     text  isfake
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...       1
# 1      Ever get the feeling your life circles the rou...       0
# 2      Why the Truth Might Get You Fired October 29, ...       1
# 3      Videos 15 Civilians Killed In Single US Airstr...       1
# 4      Print \nAn Iranian woman has been sentenced to...       1
# ...                                                  ...     ...
# 20795  Rapper T. I. unloaded on black celebrities who...       0
# 20796  When the Green Bay Packers lost to the Washing...       0
# 20797  The Macy’s of today grew from the union of sev...       0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...       1
# 20799    David Swanson is an author, activist, journa...       1
#
# [20800 rows x 2 columns]

# %%
df12['isfake']=0

# %%
df12.drop(columns=['title'], inplace=True)
df12.drop(columns=['subject'], inplace=True)
df12.drop(columns=['date'], inplace=True)

# %%
df12
# Out:
#                                                     text  isfake
# 0      WASHINGTON (Reuters) - The head of a conservat...       0
# 1      WASHINGTON (Reuters) - Transgender people will...       0
# 2      WASHINGTON (Reuters) - The special counsel inv...       0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...       0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...       0
# ...                                                  ...     ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...       0
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...       0
# 21414  MINSK (Reuters) - In the shadow of disused Sov...       0
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...       0
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...       0
#
# [21417 rows x 2 columns]

# %%
df=pd.concat([df1,df3,df4,df5,df6,df2,df7,df8,df9,df11,df12]).reset_index(drop=True)

# %%
df.dropna(subset=['text'],inplace=True)

# %%
df.isnull().sum()
# Out:
# text      0
# isfake    0
# dtype: int64

# %%
df.to_csv(r'/content/drive/My Drive/fnd-usingML/dataset/cleaned/data.csv', index = None, header=True)

# %%
import random

# %%
df
# Out:
#                                                      text isfake
# 0       Daniel Greenfield, a Shillman Journalism Fello...      1
# 1       Google Pinterest Digg Linkedin Reddit Stumbleu...      1
# 2       U.S. Secretary of State John F. Kerry said Mon...      0
# 3       — Kaydee King (@KaydeeKing) November 9, 2016 T...      1
# 4       It's primary day in New York and front-runners...      0
# ...                                                   ...    ...
# 112763  BRUSSELS (Reuters) - NATO allies on Tuesday we...      0
# 112764  LONDON (Reuters) - LexisNexis, a provider of l...      0
# 112765  MINSK (Reuters) - In the shadow of disused Sov...      0
# 112766  MOSCOW (Reuters) - Vatican Secretary of State ...      0
# 112767  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      0
#
# [112514 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size = 0.2)

# %%
train, val = train_test_split(train, test_size = 0.25)

# %%
train.to_csv(r'/content/drive/My Drive/fnd-usingML/dataset/cleaned/train.csv', index = None, header=True)
test.to_csv(r'/content/drive/My Drive/fnd-usingML/dataset/cleaned/test.csv', index = None, header=True)
val.to_csv(r'/content/drive/My Drive/fnd-usingML/dataset/cleaned/val.csv', index = None, header=True)

# %%
val
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22e33626e689> in <module>()
# ----> 1 val
#
# NameError: name 'val' is not defined
